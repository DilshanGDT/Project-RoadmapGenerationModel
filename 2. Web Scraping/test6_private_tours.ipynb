# %% [markdown]
# Scraped along the way upto the end

# %%
# Cell 1: Import Libraries
import requests
from bs4 import BeautifulSoup
import logging
import csv
import time
import json
import re

# %%
# Cell 2: Set up Base URL and Headers
# Define a base URL without the offset parameter for pagination
# The 'oaX' offset will be inserted dynamically
base_url = 'https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-Sri_Lanka.html'

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
}

print("Headers configured successfully")
# Out:
# Headers configured successfully

# %%
# Initialize a list to store all scraped places from all pages
all_places_data = []

# --- Pagination Control Variables ---
offset = 0 # Starting offset for the first page
total_items = float('inf') # Will be updated after scraping the first page
items_per_page = 30 # Number of items displayed per page on Tripadvisor

# Cell 3 & 4: Create Session, Make Request, Parse, and Extract (now within a loop for pagination)
session = requests.Session()
session.headers.update(headers)

# %%
# Loop through pages until all items are collected
while offset < total_items:
    
    print(f"\n--- Current Loop Iteration ---")
    print(f"Current offset before URL construction: {offset}")

    if offset == 0:
        current_page_url = base_url
        print(current_page_url)
    else:
        # Example: 'Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html'
        # We split the base_url to insert the offset parameter correctly
        parts = base_url.rsplit('-Sri_Lanka.html', 1)
        current_page_url = f"{parts[0]}-oa{offset}-Sri_Lanka.html"
        print(current_page_url)

    print(f"Constructed URL for this page: {current_page_url}")

    # --- MODIFIED: Add retry logic for requests ---
    max_retries = 3 # Try up to 3 times for a failed request
    for attempt in range(1, max_retries + 1):

        try:
            print(f"Attempt {attempt} for URL: {current_page_url}") # New print for retry info
            response = session.get(current_page_url, timeout=20) # <--- CHANGED: Increased timeout to 20 seconds
            response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)

            print(f"✅ Status Code for {current_page_url}: {response.status_code}")
            break # Break out of the retry loop if request is successful

        except requests.exceptions.Timeout as e:
            print(f"❌ Timeout error on attempt {attempt} for {current_page_url}: {e}")
            if attempt < max_retries:
                sleep_time = 5 * attempt # Exponential backoff: 5s, 10s, 15s delay
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
            else:
                print(f"Max retries reached for {current_page_url}. Skipping this page.")
                response = None # Set response to None to indicate failure
                break # Break out of retry loop if max attempts reached

        except requests.exceptions.RequestException as e:
            print(f"❌ Request failed on attempt {attempt} for {current_page_url}: {e}")
            if attempt < max_retries:
                sleep_time = 5 * attempt # Exponential backoff
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
            else:
                print(f"Max retries reached for {current_page_url}. Skipping this page.")
                response = None # Set response to None to indicate failure
                
    # If response is None after retries, skip processing this page and move to next offset
    if response is None:
        offset += items_per_page
        time.sleep(2) # Still add a small delay before attempting next page
        continue # Skip to the next iteration of the while loop

    # Parse the HTML content for the current page
    soup = BeautifulSoup(response.text, 'html.parser')
    print("🍲 BeautifulSoup parsing completed for current page")

    # --- Extract Total Items from the first page (only once) ---
    if offset == 0:
        total_items_text_tag = soup.find('div', class_='Ci')
        if total_items_text_tag:
            full_text = total_items_text_tag.get_text(strip=True)
            match = re.search(r'of\s*([\d,]+)', full_text)
            if match:
                total_items = int(match.group(1).replace(',', ''))
                print(f"🔢 Total items identified for scraping: {total_items}")
            else:
                print("⚠️ Could not find total number of items from the first page. Assuming only one page.")
                total_items = items_per_page # Fallback: if total items not found, only process the first page
        else:
            print("⚠️ Total items text element not found. Assuming only one page.")
            total_items = items_per_page # Fallback: if element not found, only process the first page

    # --- Data Extraction Logic (your existing robust extraction) ---
    listings = soup.find_all('article', class_='GTuVU XJlaI rHoxO')
    print(f"Found {len(listings)} listings on this page.")

    if not listings:
        print(f"🚫 No new listings found on {current_page_url}. This might be the last page or an empty page. Ending scrape.")
        break # Exit loop if no listings are found on the current page

    for listing in listings:
        place_details = {}

        # Extract Title
        title_tag = listing.find('h3', class_='biGQs _P fiohW OgHoE')
        if title_tag:
            title_text = title_tag.get_text(strip=True)
            place_details['title'] = re.sub(r'^\d+\.\s*', '', title_text).strip()
        else:
            place_details['title'] = 'N/A'

        # Extract Image links
        image_links = []
        image_container = listing.find('div', class_='IdURT w carousel UznXc wSSLS')
        if image_container:
            img_tags = image_container.find_all('img', src=True)
            for img_tag in img_tags:
                src = img_tag['src']
                if not src.startswith('data:image/svg+xml'):
                    if src.startswith('//'):
                        src = 'https:' + src
                    image_links.append(src)
        place_details['image_links'] = image_links if image_links else 'N/A'

        # Extract Rating
        rating_tag = listing.find('div', {'data-automation': 'bubbleRatingValue'})
        if rating_tag:
            place_details['rating'] = rating_tag.find('span').get_text(strip=True)
        else:
            place_details['rating'] = 'N/A'

        # Extract Total Reviews
        reviews_tag = listing.find('div', {'data-automation': 'bubbleLabel'})
        if reviews_tag:
            place_details['total_reviews'] = reviews_tag.get_text(strip=True)
        else:
            place_details['total_reviews'] = 'N/A'

        # Extract Recommendation
        recommendation_tag = listing.find('span', class_='biGQs _P pZUbB egaXP ZNjnF', string=lambda text: text and 'Recommended by' in text)
        if recommendation_tag:
            place_details['recommendation'] = recommendation_tag.get_text(strip=True)
        else:
            place_details['recommendation'] = 'N/A'

        # Extract Type
        type_div = listing.find('div', class_='alPVI eNNhq PgLKC tnGGX yzLvM')
        if type_div:
            type_element = None
            all_text_divs = type_div.find_all('div', class_='biGQs _P pZUbB ZNjnF')
            for div in all_text_divs:
                if not div.find_parent('div', class_='bRMrl _Y K fOSqw') and \
                   not div.find_parent('div', {'data-automation': 'listCardDescription'}) and \
                   not div.find_parent('div', {'data-automation': 'cardPrice'}) and \
                   not "cancellation" in div.get_text(strip=True).lower() and \
                   not "recommended by" in div.get_text(strip=True).lower():
                    type_element = div
                    break
            if type_element:
                place_details['type'] = type_element.get_text(strip=True)
            else:
                place_details['type'] = 'N/A'
        else:
            place_details['type'] = 'N/A'

        # Extract Travel Duration
        duration_tag = listing.find('div', class_='bRMrl _Y K fOSqw')
        if duration_tag:
            duration_element = duration_tag.find('div', class_='biGQs _P pZUbB ZNjnF')
            if duration_element:
                place_details['travel_duration'] = duration_element.get_text(strip=True)
            else:
                place_details['travel_duration'] = 'N/A'
        else:
            place_details['travel_duration'] = 'N/A'

        # Extract Description
        description_tag = listing.find('div', {'data-automation': 'listCardDescription'})
        if description_tag:
            span_tag = description_tag.find('span', class_='SwTtt')
            if span_tag:
                description_text = span_tag.get_text(strip=True).replace('\n', ' ').strip()
                if not description_text.endswith('…') and '…' in span_tag.text:
                    description_text += '…'
                place_details['description'] = description_text
            else:
                place_details['description'] = 'N/A'
        else:
            place_details['description'] = 'N/A'

        # Extract Starting Price
        price_tag = listing.find('div', {'data-automation': 'cardPrice'})
        if price_tag:
            place_details['starting_price'] = price_tag.get_text(strip=True)
        else:
            place_details['starting_price'] = 'N/A'
        pass
        all_places_data.append(place_details)

    # Increment the offset for the next page
    offset += items_per_page
    print(f"Offset for next page: {offset}")

    # Add a delay between requests to be polite and avoid being blocked
    time.sleep(3) # IMPORTANT: Adjust this value as needed, typically 1-5 seconds

# Final output: print all collected data after the loop finishes
print(f"\n✅ Scraped {len(all_places_data)} items across all pages.")
print(json.dumps(all_places_data, indent=2, ensure_ascii=False))
# Out:
# --- Current Loop Iteration ---
# Current offset before URL construction: 0
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# 🔢 Total items identified for scraping: 3175
# Found 30 listings on this page.
# Offset for next page: 30
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 30
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa30-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa30-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa30-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa30-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 60
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 60
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa60-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa60-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa60-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa60-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 90
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 90
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa90-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa90-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa90-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa90-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 120
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 120
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa120-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa120-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa120-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa120-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 150
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 150
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa150-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa150-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa150-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa150-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 180
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 180
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa180-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa180-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa180-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa180-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 210
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 210
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa210-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa210-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa210-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa210-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 240
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 240
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa240-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa240-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa240-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa240-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 270
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 270
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa270-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa270-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa270-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa270-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 300
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 300
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa300-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa300-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa300-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa300-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 330
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 330
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa330-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa330-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa330-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa330-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 360
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 360
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa360-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa360-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa360-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa360-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 390
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 390
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa390-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa390-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa390-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa390-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 420
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 420
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa420-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa420-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa420-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa420-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 450
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 450
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa450-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa450-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa450-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa450-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 480
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 480
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa480-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa480-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa480-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa480-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 510
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 510
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa510-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa510-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa510-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa510-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 540
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 540
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa540-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa540-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa540-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa540-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 570
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 570
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa570-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa570-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa570-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa570-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 600
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 600
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa600-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa600-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa600-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa600-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 630
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 630
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa630-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa630-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa630-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa630-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 660
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 660
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa660-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa660-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa660-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa660-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 690
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 690
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa690-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa690-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa690-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa690-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 720
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 720
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa720-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa720-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa720-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa720-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 750
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 750
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa750-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa750-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa750-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa750-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 780
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 780
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa780-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa780-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa780-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa780-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 810
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 810
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa810-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa810-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa810-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa810-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 840
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 840
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa840-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa840-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa840-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa840-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 870
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 870
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa870-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa870-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa870-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa870-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 900
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 900
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa900-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa900-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa900-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa900-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 930
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 930
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa930-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa930-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa930-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa930-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 960
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 960
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa960-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa960-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa960-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa960-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 990
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 990
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa990-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa990-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa990-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa990-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1020
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1020
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1020-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1020-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1020-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1020-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1050
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1050
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1050-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1050-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1050-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1050-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1080
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1080
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1080-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1080-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1080-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1080-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1110
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1110
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1110-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1110-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1110-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1110-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1140
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1140
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1140-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1140-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1140-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1140-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1170
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1170
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1170-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1170-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1170-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1170-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1200
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1200
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1200-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1200-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1200-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1200-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1230
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1230
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1230-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1230-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1230-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1230-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1260
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1260
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1260-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1260-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1260-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1260-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1290
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1290
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1290-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1290-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1290-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1290-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1320
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1320
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1320-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1320-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1320-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1320-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1350
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1350
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1350-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1350-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1350-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1350-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1380
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1380
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1380-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1380-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1380-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1380-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1410
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1410
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1410-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1410-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1410-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1410-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1440
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1440
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1440-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1440-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1440-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1440-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1470
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1470
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1470-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1470-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1470-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1470-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1500
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1500
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1500-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1500-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1500-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1500-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1530
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1530
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1530-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1530-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1530-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1530-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1560
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1560
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1560-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1560-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1560-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1560-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1590
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1590
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1590-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1590-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1590-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1590-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1620
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1620
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1620-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1620-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1620-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1620-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1650
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1650
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1650-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1650-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1650-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1650-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1680
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1680
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1680-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1680-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1680-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1680-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1710
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1710
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1710-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1710-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1710-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1710-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1740
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1740
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1740-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1740-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1740-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1740-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1770
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1770
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1770-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1770-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1770-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1770-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1800
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1800
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1800-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1800-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1800-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1800-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1830
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1830
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1830-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1830-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1830-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1830-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1860
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1860
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1860-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1860-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1860-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1860-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1890
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1890
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1890-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1890-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1890-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1890-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1920
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1920
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1920-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1920-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1920-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1920-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1950
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1950
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1950-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1950-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1950-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1950-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1980
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1980
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1980-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1980-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1980-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa1980-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2010
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2010
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2010-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2010-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2010-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2010-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2040
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2040
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2040-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2040-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2040-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2040-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2070
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2070
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2070-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2070-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2070-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2070-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2100
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2100
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2100-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2100-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2100-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2100-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2130
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2130
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2130-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2130-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2130-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2130-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2160
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2160
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2160-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2160-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2160-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2160-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2190
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2190
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2190-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2190-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2190-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2190-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2220
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2220
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2220-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2220-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2220-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2220-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2250
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2250
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2250-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2250-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2250-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2250-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2280
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2280
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2280-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2280-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2280-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2280-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 2310
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 2310
# https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2310-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2310-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c42-t235-oa2310-Sri_Lanka.html
# ...
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/76/82/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "2 hours",
#     "description": "Pick up point: Colombo City Helipad (MOD Helipad), Landing point: Anuradhapura Airfield, Flying time: 120 mts (Both ways…",
#     "starting_price": "$3,150"
#   },
#   {
#     "title": "Bentota River Safari: Crocodiles, Monkeys, Birds, Mangrove Forest",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/67/88/9f/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Eco Tours",
#     "travel_duration": "2 hours",
#     "description": "Begin your Bentota River Safari with a warm welcome from our professional guide at the meeting point. You’ll receive a safety…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "one day excursion galle",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/de/69/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Car Tours",
#     "travel_duration": "6+ hours",
#     "description": "GTS TOURS SRI LANKA carries the motto \"Explore the Island with Us\" Likewise, our service focuses  on traveling well, whilst…",
#     "starting_price": "$120"
#   },
#   {
#     "title": "Sigiriya and Dambulla Cave Temple Private Day Trip From Bentota",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/1b/2f/c2/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "10–12 hours",
#     "description": "Embark on an unforgettable adventure with our unique Sri Lankan experience! Start your day with a breathtaking sunrise at…",
#     "starting_price": "$120"
#   },
#   {
#     "title": "Trincomalee City Tour from Sigiriya",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/9d/0b/5d/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "This tour takes you to the ancient harbor city of Trincomalee on the beautiful Eastern Coast of Sri Lanka. Explore nature…",
#     "starting_price": "$80"
#   },
#   {
#     "title": "Scenic Galle by Airplane from Koggala Airport (KCT)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8a/b6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "2 hours",
#     "description": "Galle is one of Sri Lanka’s most famous destinations, a historic city with the famous Dutch Fort build in the 17th Century…",
#     "starting_price": "$216"
#   },
#   {
#     "title": "Kalawewa National Park Guided 4WD Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/27/94/7b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "The imposing Kala Wewa and Balalu Wewa tanks built in the 5th century BC by King Dhatusena adorns the 6000-hectare Kalawewa…",
#     "starting_price": "$63"
#   },
#   {
#     "title": "Sri Lanka 7 Day Tour | All Inclusive",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/60/95/5c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Multi-day Tours",
#     "travel_duration": "3+ days",
#     "description": "Enjoy this 7 Day tour by visiting iconic attractions and destinations in Sri Lanka with your own private driver/guide. Your…",
#     "starting_price": "$881"
#   },
#   {
#     "title": "8 day tour of Beaches & Hill Country in Sri Lanka",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/01/1d/99/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "Get a comprehensive tour of the island of Sir Lanka and benefit from personalized attention from a dedicated guide. This…",
#     "starting_price": "$1,360"
#   },
#   {
#     "title": "Private 8 day tour in Sri Lanka 2020 - Only for groups above 7 pax.",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5d/d5/f5/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Multi-day Tours",
#     "travel_duration": "3+ days",
#     "description": "Spend 8 days in Sri Lanka experiencing its beautiful cities, historical and wildlife attractions, and UNESCO World Heritage…",
#     "starting_price": "$980"
#   },
#   {
#     "title": "Full Day Nuwara Eliya City Tour | From Kandy",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/a4/1d/44/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Go into the chilly highlands of Sri Lanka and take in the spectacular mountain top views and majestic waterfalls. Sri Lanka…",
#     "starting_price": "$71"
#   },
#   {
#     "title": "Southern Coast Highlights from Beruwala",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/71/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "This one-day tour offers you the opportunity to tour the best attractions on the Southern coast of tropical Sri Lanka. Visit…",
#     "starting_price": "$53"
#   },
#   {
#     "title": "Adventure tour in Sri Lanka for 9 days",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/53/db/17/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "3+ days",
#     "description": "Adventure tour in Sri Lanka for 9 days is a full guide on how to spend a 9-day wildlife tour in Sri Lanka, don't skip any…",
#     "starting_price": "$1,016"
#   },
#   {
#     "title": "Adisham Rail Tour from Ella",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/19/95/6b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Rail Tours",
#     "travel_duration": "6+ hours",
#     "description": "Visit the famous Adisham Bungalow by train. Enjoy the misty mountains and other colorful sights as you pass along during…",
#     "starting_price": "$75"
#   },
#   {
#     "title": "Waterfall Hunt Hiking Tour from Kandy",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/70/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "This tour takes you on an adventurous hike and drive through the lush tropical wilderness of Sri Lanka, on a quest to search…",
#     "starting_price": "$96"
#   },
#   {
#     "title": "Private Day Tour to Polonnaruwa with Driver from Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1c/cb/99/e7/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "During this day Tour from Negombo to Polonnaruwa, we will be sight-seeing areas in the following destinations: Thuparama…",
#     "starting_price": "$145"
#   },
#   {
#     "title": "Private Nuwara Eliya Day Tour from Kandy with Pick up",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1c/cc/71/30/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Need help in planning a private budget tour to Sri Lanka? Whatever your travel preference, you will find suitable Sri Lanka…",
#     "starting_price": "$60"
#   },
#   {
#     "title": "Scenic Adam's Peak by Helicopter from Koggala",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/77/bb/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "1–2 hours",
#     "description": "Koggala to Adam's Peak Helicopter tour is known as one of the most scenic helicopter tours in the world.This tour pick up…",
#     "starting_price": "$1,488"
#   },
#   {
#     "title": "Chauffeur Driven Van (Large) Rental",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/87/c3/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Overnight Tours",
#     "travel_duration": "2 days",
#     "description": "Rent a van for your visit to Sri Lanka. Our vehicle rental service is conducted by English-speaking chauffeur-guides who…",
#     "starting_price": "$113"
#   },
#   {
#     "title": "Scenic Adam's Peak by Helicopter from Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/74/ea/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Extreme Sports",
#     "travel_duration": "1–2 hours",
#     "description": "Negombo to Adam's Peak Helicopter tour is known as one of the most scenic helicopter tours in the world.The tour picks up…",
#     "starting_price": "$1,310"
#   },
#   {
#     "title": "Polonnaruwa Ancient Kingdom and Wild Elephant Safari from Dambulla",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8d/69/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "This tour takes you to Polonnaruwa and Minneriya, on a remarkable archaeological and nature-filled journey. Wonder at the…",
#     "starting_price": "$81"
#   },
#   {
#     "title": "Sensation of the World (14 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/6c/9f/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Multi-day Tours",
#     "travel_duration": "3+ days",
#     "description": "14 Days in Paradise Island. What more could you ask for? When you got two weeks in a land so unique, you just have to experience…",
#     "starting_price": "$442"
#   },
#   {
#     "title": "Wasgamuwa National Park Safari from Habarana",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/19/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Wasgamuwa National Park is a haven for many species of flora and displaced fauna. Nature lovers find Wasgamuwa interesting…",
#     "starting_price": "$89"
#   },
#   {
#     "title": "Hidden Temples and Secluded Coastlines from Galle City",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/10/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "You will be starting your tour at 07.00 hrs from the Hotel in Galle. After being picked up by your chauffeur guide, you …",
#     "starting_price": "$47"
#   },
#   {
#     "title": "Explore Gem Mines in Rathnapura from Kalutara",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8d/00/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Ratnapura owns gems of ranging quality. Precious and semi-precious stones such as Sapphires, Rubies, Amethysts and the tools…",
#     "starting_price": "$61"
#   },
#   {
#     "title": "Temples and Nature (22 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8c/f7/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "Sri Lanka though a renowned leisure destination for its mesmeric hill country, exquisite beaches, and fascinating cultural…",
#     "starting_price": "$1,244"
#   },
#   {
#     "title": "Escapade to the East (10 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8c/fa/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "This tour is for those who are looking forward to a tour including both Heritage and a relaxing beach stay along with a …",
#     "starting_price": "$404"
#   },
#   {
#     "title": "Explore Belilena Cave from Mount Lavinia",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/ad/a1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Venture into Belilena Caves on a private 9-hour tour with a friendly guide. Hike through the dense jungles around Kitulgala…",
#     "starting_price": "$111"
#   },
#   {
#     "title": "Ramayana Trail (5 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8d/76/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Multi-day Tours",
#     "travel_duration": "3+ days",
#     "description": "In this tour that proves the truth behind the Hindu literary epic of Ramayana, worship at the Sita Amman Temple in Seetha…",
#     "starting_price": "$218"
#   },
#   {
#     "title": "Private Sri Lanka Multi Day Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/85/58/b8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Rail Tours",
#     "travel_duration": "3+ days",
#     "description": "Experience Sri Lanka’s diverse landscapes and rich culture in a 15-day adventure. Begin in Negombo with a city tour exploring…",
#     "starting_price": "$15"
#   },
#   {
#     "title": "6-Day Coastal Honeymoon Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5f/8d/d7/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Romantic Tours",
#     "travel_duration": "3+ days",
#     "description": "This tour covers some of the most exciting coastal activities in the south beach of Sri Lanka with all honeymoon specials…",
#     "starting_price": "$1,000"
#   }
# ]

# %%
print(len(all_places_data))
# Out:
# 3175

# %%
# Cell X: Save to CSV File
import csv # Ensure this import is at the top of your script if not already there

csv_file_name = 'sri_lanka_private_tours.csv'

# Determine the fieldnames (column headers) from the keys of the first dictionary
# This assumes all dictionaries have the same keys.
if all_places_data:
    fieldnames = list(all_places_data[0].keys()) # Convert to list for DictWriter
else:
    fieldnames = [] # Handle case where no data was scraped

try:
    with open(csv_file_name, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader() # Write the header row
        for row in all_places_data:
            # Ensure image_links are joined into a string if they are a list, for CSV compatibility
            if isinstance(row.get('image_links'), list):
                cleaned_image_links = []
                for link in row['image_links']:
                    # Remove query parameters from each link
                    # This splits the URL at the first '?' and takes the first part
                    cleaned_link = link.split('?', 1)[0]
                    cleaned_image_links.append(cleaned_link)
                
                row['image_links'] = ', '.join(cleaned_image_links) # Join the cleaned links
            
            writer.writerow(row) # Write each row

    print(f"\n✅ Data successfully saved to {csv_file_name}")

except IOError as e:
    print(f"❌ Error writing to CSV file {csv_file_name}: {e}")
# Out:
# ✅ Data successfully saved to sri_lanka_private_tours.csv
