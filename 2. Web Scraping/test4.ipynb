# %%
# Cell 1: Import Libraries
import requests
from bs4 import BeautifulSoup
import logging
import csv
import time
import json # Ensure json is imported for printing structured data
import re # Ensure re is imported for cleaning title.

# %%
# Cell 2: Set up URL and Headers
url = 'https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html'

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    # Note: Removed Accept-Encoding to fix garbled text issue
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
}

print("Headers configured successfully")
# Out:
# Headers configured successfully

# %%
# Cell 3: Create Session and Make Request
session = requests.Session()
session.headers.update(headers)

try:
    response = session.get(url, timeout=10)
    response.raise_for_status()
    
    print(f"✅ Status Code: {response.status_code}")
    print(f"📦 Content Encoding: {response.headers.get('Content-Encoding', 'None')}")
    print(f"📄 Content Type: {response.headers.get('Content-Type', 'None')}")
    print(f"📏 Content Length: {len(response.content)} bytes")
    
except requests.exceptions.RequestException as e:
    print(f"❌ Request failed: {e}")
# Out:
# ✅ Status Code: 200
# 📦 Content Encoding: gzip
# 📄 Content Type: text/html; charset=utf-8
# 📏 Content Length: 1966300 bytes

# %%
# Cell 4: Parse with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

print("🍲 BeautifulSoup parsing completed")
print(f"📊 Found {len(soup.find_all())} HTML elements")
# Out:
# 🍲 BeautifulSoup parsing completed
# 📊 Found 7047 HTML elements

# %% [markdown]
# Taken from a saved text

# %%
with open("scraped_page_06.txt", "w", encoding="utf-8") as file:
    file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import json
import re

with open('scraped_page_06.txt', 'r', encoding='utf-8') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

places = []

# Find all article tags that represent a "place" or listing
listings = soup.find_all('article', class_='GTuVU XJlaI rHoxO')

for listing in listings:
    place_details = {}

    # Extract Title
    title_tag = listing.find('h3', class_='biGQs _P fiohW OgHoE')
    if title_tag:
        # Removing leading numbers (e.g., "1.", "2.", "30.")
        title_text = title_tag.get_text(strip=True)
        place_details['title'] = re.sub(r'^\d+\.\s*', '', title_text).strip()
    else:
        place_details['title'] = 'N/A'

    # Extract Image links
    image_links = []
    # Find the main div that contains the image carousel
    image_container = listing.find('div', class_='IdURT w carousel UznXc wSSLS')
    if image_container:
        # Find all img tags within this container that have a 'src' attribute
        # and filter out data URI images (placeholders)
        img_tags = image_container.find_all('img', src=True)
        for img_tag in img_tags:
            src = img_tag['src']
            if not src.startswith('data:image/svg+xml'):
                # Handle relative URLs if any (TripAdvisor generally uses full URLs or // scheme relative)
                if src.startswith('//'):
                    src = 'https:' + src
                image_links.append(src)
    place_details['image_links'] = image_links if image_links else 'N/A'

    # Extract Rating
    rating_tag = listing.find('div', {'data-automation': 'bubbleRatingValue'})
    if rating_tag:
        place_details['rating'] = rating_tag.find('span').get_text(strip=True)
    else:
        place_details['rating'] = 'N/A'

    # Extract Total Reviews
    reviews_tag = listing.find('div', {'data-automation': 'bubbleLabel'})
    if reviews_tag:
        place_details['total_reviews'] = reviews_tag.get_text(strip=True)
    else:
        place_details['total_reviews'] = 'N/A'

    # Extract Recommendation
    recommendation_tag = listing.find('span', class_='biGQs _P pZUbB egaXP ZNjnF', string=lambda text: text and 'Recommended by' in text)
    if recommendation_tag:
        place_details['recommendation'] = recommendation_tag.get_text(strip=True)
    else:
        place_details['recommendation'] = 'N/A'

    # Extract Type
    # This might require more specific targeting as 'biGQs _P pZUbB ZNjnF' is generic
    # Based on the example, it's often the first strong text in the description block after the title
    type_div = listing.find('div', class_='alPVI eNNhq PgLKC tnGGX yzLvM')
    if type_div:
        # Looking for the specific div that contains the type, which is usually right after the title section
        # and not part of 'bRMrl _Y K fOSqw' (travel duration) or 'DnkDV' (description)
        # This selector is a bit tricky due to generic class names, might need refinement if it pulls wrong text
        # Attempting to find the first 'biGQs _P pZUbB ZNjnF' within the main detail block that isn't part of duration or description
        type_element = None
        all_text_divs = type_div.find_all('div', class_='biGQs _P pZUbB ZNjnF')
        for div in all_text_divs:
            # Heuristic: check if it's not part of known other fields
            if not div.find_parent('div', class_='bRMrl _Y K fOSqw') and \
               not div.find_parent('div', {'data-automation': 'listCardDescription'}) and \
               not div.find_parent('div', {'data-automation': 'cardPrice'}) and \
               not "cancellation" in div.get_text(strip=True).lower() and \
               not "recommended by" in div.get_text(strip=True).lower():
                type_element = div
                break
        if type_element:
            place_details['type'] = type_element.get_text(strip=True)
        else:
            place_details['type'] = 'N/A'
    else:
        place_details['type'] = 'N/A'

    # Extract Travel Duration
    duration_tag = listing.find('div', class_='bRMrl _Y K fOSqw')
    if duration_tag:
        duration_element = duration_tag.find('div', class_='biGQs _P pZUbB ZNjnF')
        if duration_element:
            place_details['travel_duration'] = duration_element.get_text(strip=True)
        else:
            place_details['travel_duration'] = 'N/A'
    else:
        place_details['travel_duration'] = 'N/A'

    # Extract Description
    description_tag = listing.find('div', {'data-automation': 'listCardDescription'})
    if description_tag:
        span_tag = description_tag.find('span', class_='SwTtt')
        if span_tag:
            description_text = span_tag.get_text(strip=True).replace('\n', ' ').strip()
            # Ensure description ends with '...' if it was truncated, but avoid double '...'
            if not description_text.endswith('…') and '…' in span_tag.text: # Check if original text had '…'
                description_text += '…'
            place_details['description'] = description_text
        else:
            place_details['description'] = 'N/A'
    else:
        place_details['description'] = 'N/A'

    # Extract Starting Price
    price_tag = listing.find('div', {'data-automation': 'cardPrice'})
    if price_tag:
        place_details['starting_price'] = price_tag.get_text(strip=True)
    else:
        place_details['starting_price'] = 'N/A'

    places.append(place_details)

print(json.dumps(places, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "title": "Ella: Transfer to Tangalle/Mirissa/Galle & Yala/Udawalawe Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/15/e8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "30",
#     "recommendation": "Recommended by 93% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "8–10 hours",
#     "description": "After pick-up from your hotel in Ella, head for Udawalawe Or Yala National Park, where you'll switch to an open concept …",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park to Visit Elephants",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/c8/cb/5e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "215",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "Attention: According to the weather conditions, Minneriya National Park is the best these days. You can see a huge number…",
#     "starting_price": "$35"
#   },
#   {
#     "title": "Special leopards safari Yala National park - 04.30 am to 11.30 am",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/02/e4/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "154",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "People who like to see more wild life this is the perfect tour with janaka safari,  we do our best for the leopard. start…",
#     "starting_price": "$49"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park - Half Day Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/d8/b1/a2/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "40",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "We arrange a Comfortable and private vehicle for you. The prices include hotel pick-up and drop-off. We offer a Knowledgeable…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Udawalawe National Park | Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/24/45/64/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "1,068",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Udawalawe National Park is a destination to see elephants. Other animals in the park include leopards, jungle cats, monkeys…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Yala National Park Special Leopard Safari Tours By Dinuka Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/e9/25/6a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "64",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "7–13 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$22"
#   },
#   {
#     "title": "Full day Safari - Yala National Park - 04.30 am to 06.00 pm with - Janaka safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/0b/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "462",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "The leopard is the key attraction to Yala National Park:   “Showing the leopard is our mission”  Other Animals  There are…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Yala National Park Wildlife Safari/ Game Drive - by Ajith Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/7c/b6/a9/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "214",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Explore breathtaking wilderness of Sri Lanka with Ajith Safari Jeep Tours. We're the only Sri Lankan safari operator mentioned…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Wilpattu National Park Safari | Jeep with Tickets",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/b2/34/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "101",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–12 hours",
#     "description": "The park is 1,317 square kilometers (131, 693 hectares) and ranges from 0 to 152 meters above sea level. Nearly one hundred…",
#     "starting_price": "$95"
#   },
#   {
#     "title": "Full day / Half Day WildlifeAdventure in Yala-National-Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/38/3b/98/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "239",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Photography Tours",
#     "travel_duration": "1 day",
#     "description": "Yala harbours 215 bird species including six endemic species of Sri Lanka. The number of mammals that has been recorded …",
#     "starting_price": "$42"
#   },
#   {
#     "title": "Minneriya National Park halfday Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/24/0c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "224",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "To reserve a national park, please choose one from the options provided. Each reservation is for one park only, and you …",
#     "starting_price": "$50"
#   },
#   {
#     "title": "Udawalawe National Park Half Day Jeep Safari (Private Tour)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/a2/b7/59/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "62",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "You have the option of either arranging for hotel pickup or heading directly to the Udawalawe National Park gate, where …",
#     "starting_price": "$24"
#   },
#   {
#     "title": "Wilpattu Half Day Safari From Anuradhapura",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/96/23/e1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "Join us for an exhilarating safari in Wilpattu National Park, starting at 5:00 AM, where you have a prime opportunity to…",
#     "starting_price": "$73"
#   },
#   {
#     "title": "Minneriya National Park Elephant Jeep Safari Private Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/af/03/0e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "35",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "3–5 hours",
#     "description": "The biggest concentration of wild Asian elephants in the entire world may be found in Sri Lanka’s Minneriya National Park…",
#     "starting_price": "$53"
#   },
#   {
#     "title": "Kumana National Park Half Day Jeep Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4d/87/c6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "32",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–6 hours",
#     "description": "visit to the Kumana National Park is a must-do activity when you holiday at Arugam Bay and we are delighted to organize …",
#     "starting_price": "$88"
#   },
#   {
#     "title": "Wilpattu National Park Jeep Safari from Negombo / Waikkal (All Inclusive)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/f6/58/d6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "83",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "10–16 hours",
#     "description": "Today you will enjoy an adventurous full-day safari at Wilpattu National Park including breakfast and lunch at the Park. …",
#     "starting_price": "$152"
#   },
#   {
#     "title": "2h Bentota River Safari: Crocodiles, Monkeys, Mangrove & more",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/68/bb/d0/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "73",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "Embark on the Bentota River Boat Safari with us and immerse yourself in a world where nature's tranquility meets wild beauty…",
#     "starting_price": "$33"
#   },
#   {
#     "title": "Day Tour from kandy to Sigiriya, Dambulla & National Park safari.",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/f1/05/3b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "14",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "Sigiriya today is a UNESCO-listed World Heritage Site. It is one of the best-preserved examples of ancient urban planning…",
#     "starting_price": "$55"
#   },
#   {
#     "title": "Safari Tour at Minneriya National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/5d/bc/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "19",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "5 hours",
#     "description": "Bunches of Elephants can be seen in their natural behavior and visitors will be amazed to see hundreds in bunch. You will…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Negombo Lagoon Boat Safari From Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/c3/72/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "8",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "This safari is a must-do for nature lovers and anyone looking for a scenic retreat because it guarantees a tranquil break…",
#     "starting_price": "$43"
#   },
#   {
#     "title": "Yala National Park Tour From Hambantota Port",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/c7/f2/14/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "31",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$48"
#   },
#   {
#     "title": "Half Day Tour to Muthurajawela, Lagoon, Dutch Canal and Mangroves",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/19/20/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "5",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "3 hours",
#     "description": "Half day tour to explore different seaside attractions with a ride through the Dutch Canal, Negombo lagoon and Muthurajawela…",
#     "starting_price": "$59"
#   },
#   {
#     "title": "Ella to Mirissa Shuttle & Safari Drive (Breakfast Included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fa/69/36/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "21",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Enjoy a seamless door to door transfer between Ella to Mirissa via Udawalawe national park. Udawalawe National Park is renowned…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Mirissa to Ella Shuttle & Safari Drive (Breakfast included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/97/f2/2c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "17",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "Key Attractions: Udawalawe National Park  Door to Door Hotel transfer:  From Mirissa, Weligama, Galle, Dickwella & suburbs…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Yala National Park Morning or Afternoon Leopard Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/0b/56/89/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "7",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "4–5 hours",
#     "description": "Our safari offers exclusive access to Yala’s wildlife in luxury 4x4 jeeps, led by expert guides. Spot leopards, elephants…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Udawalawe Safari DayTrip frm Bentota/Kalutara/Ahungalla/Hikkaduwa",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5d/c3/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "55",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "10–12 hours",
#     "description": "Udawalawe Safari Private Day Trip is organized by Bentota Travel Mart (BTM) for the tourists who stay in Wadduwa, Waskaduwa…",
#     "starting_price": "$155"
#   },
#   {
#     "title": "Udawalawe National Park | 4 Hours Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/37/af/10/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "112",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Safaris",
#     "travel_duration": "4 hours",
#     "description": "Experience a 4-Hour Safari Tour in Udawalawe!  Discover Udawalawe National Park on our 4-hour safari tour. Ideal for those…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Leopard Safari Tour in Yala National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/a6/42/f5/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "252",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Yala National Park boasts one of the densest populations of leopards in the world, and this great-value safari focuses on…",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Minneriya National Park Half day Jeep Safari with Hotel Pickup",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/b9/4b/50/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "28",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Experience the Minneriya National Park Jeep Safari, renowned for hosting South Asia's largest elephant gathering. Choose…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Minneriya National Park private safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/00/b3/d8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "93",
#     "recommendation": "Recommended by 95% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "• Morning (5.30am) or afternoon (2pm) - arrange with guide after booking.   • Hotel Pickup+and drop free of charges  only…",
#     "starting_price": "$60"
#   }
# ]

# %% [markdown]
# direct extracting

# %%
places = []

# Find all article tags that represent a "place" or listing
listings = soup.find_all('article', class_='GTuVU XJlaI rHoxO')

for listing in listings:
    place_details = {}

    # Extract Title
    title_tag = listing.find('h3', class_='biGQs _P fiohW OgHoE')
    if title_tag:
        # Removing leading numbers (e.g., "1.", "2.", "30.")
        title_text = title_tag.get_text(strip=True)
        place_details['title'] = re.sub(r'^\d+\.\s*', '', title_text).strip()
    else:
        place_details['title'] = 'N/A'

    # Extract Image links
    image_links = []
    # Find the main div that contains the image carousel
    image_container = listing.find('div', class_='IdURT w carousel UznXc wSSLS')
    if image_container:
        # Find all img tags within this container that have a 'src' attribute
        # and filter out data URI images (placeholders)
        img_tags = image_container.find_all('img', src=True)
        for img_tag in img_tags:
            src = img_tag['src']
            if not src.startswith('data:image/svg+xml'):
                # Handle relative URLs if any (TripAdvisor generally uses full URLs or // scheme relative)
                if src.startswith('//'):
                    src = 'https:' + src
                image_links.append(src)
    place_details['image_links'] = image_links if image_links else 'N/A'

    # Extract Rating
    rating_tag = listing.find('div', {'data-automation': 'bubbleRatingValue'})
    if rating_tag:
        place_details['rating'] = rating_tag.find('span').get_text(strip=True)
    else:
        place_details['rating'] = 'N/A'

    # Extract Total Reviews
    reviews_tag = listing.find('div', {'data-automation': 'bubbleLabel'})
    if reviews_tag:
        place_details['total_reviews'] = reviews_tag.get_text(strip=True)
    else:
        place_details['total_reviews'] = 'N/A'

    # Extract Recommendation
    recommendation_tag = listing.find('span', class_='biGQs _P pZUbB egaXP ZNjnF', string=lambda text: text and 'Recommended by' in text)
    if recommendation_tag:
        place_details['recommendation'] = recommendation_tag.get_text(strip=True)
    else:
        place_details['recommendation'] = 'N/A'

    # Extract Type
    type_div = listing.find('div', class_='alPVI eNNhq PgLKC tnGGX yzLvM')
    if type_div:
        type_element = None
        all_text_divs = type_div.find_all('div', class_='biGQs _P pZUbB ZNjnF')
        for div in all_text_divs:
            if not div.find_parent('div', class_='bRMrl _Y K fOSqw') and \
               not div.find_parent('div', {'data-automation': 'listCardDescription'}) and \
               not div.find_parent('div', {'data-automation': 'cardPrice'}) and \
               not "cancellation" in div.get_text(strip=True).lower() and \
               not "recommended by" in div.get_text(strip=True).lower():
                type_element = div
                break
        if type_element:
            place_details['type'] = type_element.get_text(strip=True)
        else:
            place_details['type'] = 'N/A'
    else:
        place_details['type'] = 'N/A'

    # Extract Travel Duration
    duration_tag = listing.find('div', class_='bRMrl _Y K fOSqw')
    if duration_tag:
        duration_element = duration_tag.find('div', class_='biGQs _P pZUbB ZNjnF')
        if duration_element:
            place_details['travel_duration'] = duration_element.get_text(strip=True)
        else:
            place_details['travel_duration'] = 'N/A'
    else:
        place_details['travel_duration'] = 'N/A'

    # Extract Description
    description_tag = listing.find('div', {'data-automation': 'listCardDescription'})
    if description_tag:
        span_tag = description_tag.find('span', class_='SwTtt')
        if span_tag:
            description_text = span_tag.get_text(strip=True).replace('\n', ' ').strip()
            if not description_text.endswith('…') and '…' in span_tag.text:
                description_text += '…'
            place_details['description'] = description_text
        else:
            place_details['description'] = 'N/A'
    else:
        place_details['description'] = 'N/A'

    # Extract Starting Price
    price_tag = listing.find('div', {'data-automation': 'cardPrice'})
    if price_tag:
        place_details['starting_price'] = price_tag.get_text(strip=True)
    else:
        place_details['starting_price'] = 'N/A'

    places.append(place_details)

print(json.dumps(places, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "title": "Ella: Transfer to Tangalle/Mirissa/Galle & Yala/Udawalawe Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/15/e8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "30",
#     "recommendation": "Recommended by 93% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "8–10 hours",
#     "description": "After pick-up from your hotel in Ella, head for Udawalawe Or Yala National Park, where you'll switch to an open concept …",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park to Visit Elephants",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/c8/cb/5e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "215",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "Attention: According to the weather conditions, Minneriya National Park is the best these days. You can see a huge number…",
#     "starting_price": "$35"
#   },
#   {
#     "title": "Special leopards safari Yala National park - 04.30 am to 11.30 am",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/02/e4/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "154",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "People who like to see more wild life this is the perfect tour with janaka safari,  we do our best for the leopard. start…",
#     "starting_price": "$49"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park - Half Day Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/d8/b1/a2/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "40",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "We arrange a Comfortable and private vehicle for you. The prices include hotel pick-up and drop-off. We offer a Knowledgeable…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Udawalawe National Park | Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/24/45/64/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "1,068",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Udawalawe National Park is a destination to see elephants. Other animals in the park include leopards, jungle cats, monkeys…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Yala National Park Special Leopard Safari Tours By Dinuka Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/e9/25/6a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "64",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "7–13 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$22"
#   },
#   {
#     "title": "Full day Safari - Yala National Park - 04.30 am to 06.00 pm with - Janaka safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/0b/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "462",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "The leopard is the key attraction to Yala National Park:   “Showing the leopard is our mission”  Other Animals  There are…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Yala National Park Wildlife Safari/ Game Drive - by Ajith Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/7c/b6/a9/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "214",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Explore breathtaking wilderness of Sri Lanka with Ajith Safari Jeep Tours. We're the only Sri Lankan safari operator mentioned…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Wilpattu National Park Safari | Jeep with Tickets",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/b2/34/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "101",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–12 hours",
#     "description": "The park is 1,317 square kilometers (131, 693 hectares) and ranges from 0 to 152 meters above sea level. Nearly one hundred…",
#     "starting_price": "$95"
#   },
#   {
#     "title": "Full day / Half Day WildlifeAdventure in Yala-National-Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/38/3b/98/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "239",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Photography Tours",
#     "travel_duration": "1 day",
#     "description": "Yala harbours 215 bird species including six endemic species of Sri Lanka. The number of mammals that has been recorded …",
#     "starting_price": "$42"
#   },
#   {
#     "title": "Minneriya National Park halfday Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/24/0c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "224",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "To reserve a national park, please choose one from the options provided. Each reservation is for one park only, and you …",
#     "starting_price": "$50"
#   },
#   {
#     "title": "Udawalawe National Park Half Day Jeep Safari (Private Tour)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/a2/b7/59/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "62",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "You have the option of either arranging for hotel pickup or heading directly to the Udawalawe National Park gate, where …",
#     "starting_price": "$24"
#   },
#   {
#     "title": "Wilpattu Half Day Safari From Anuradhapura",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/96/23/e1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "Join us for an exhilarating safari in Wilpattu National Park, starting at 5:00 AM, where you have a prime opportunity to…",
#     "starting_price": "$73"
#   },
#   {
#     "title": "Minneriya National Park Elephant Jeep Safari Private Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/af/03/0e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "35",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "3–5 hours",
#     "description": "The biggest concentration of wild Asian elephants in the entire world may be found in Sri Lanka’s Minneriya National Park…",
#     "starting_price": "$53"
#   },
#   {
#     "title": "Kumana National Park Half Day Jeep Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4d/87/c6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "32",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–6 hours",
#     "description": "visit to the Kumana National Park is a must-do activity when you holiday at Arugam Bay and we are delighted to organize …",
#     "starting_price": "$88"
#   },
#   {
#     "title": "Wilpattu National Park Jeep Safari from Negombo / Waikkal (All Inclusive)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/f6/58/d6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "83",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "10–16 hours",
#     "description": "Today you will enjoy an adventurous full-day safari at Wilpattu National Park including breakfast and lunch at the Park. …",
#     "starting_price": "$152"
#   },
#   {
#     "title": "2h Bentota River Safari: Crocodiles, Monkeys, Mangrove & more",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/68/bb/d0/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "73",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "Embark on the Bentota River Boat Safari with us and immerse yourself in a world where nature's tranquility meets wild beauty…",
#     "starting_price": "$33"
#   },
#   {
#     "title": "Day Tour from kandy to Sigiriya, Dambulla & National Park safari.",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/f1/05/3b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "14",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "Sigiriya today is a UNESCO-listed World Heritage Site. It is one of the best-preserved examples of ancient urban planning…",
#     "starting_price": "$55"
#   },
#   {
#     "title": "Safari Tour at Minneriya National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/5d/bc/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "19",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "5 hours",
#     "description": "Bunches of Elephants can be seen in their natural behavior and visitors will be amazed to see hundreds in bunch. You will…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Negombo Lagoon Boat Safari From Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/c3/72/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "8",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "This safari is a must-do for nature lovers and anyone looking for a scenic retreat because it guarantees a tranquil break…",
#     "starting_price": "$43"
#   },
#   {
#     "title": "Yala National Park Tour From Hambantota Port",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/c7/f2/14/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "31",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$48"
#   },
#   {
#     "title": "Half Day Tour to Muthurajawela, Lagoon, Dutch Canal and Mangroves",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/19/20/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "5",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "3 hours",
#     "description": "Half day tour to explore different seaside attractions with a ride through the Dutch Canal, Negombo lagoon and Muthurajawela…",
#     "starting_price": "$59"
#   },
#   {
#     "title": "Ella to Mirissa Shuttle & Safari Drive (Breakfast Included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fa/69/36/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "21",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Enjoy a seamless door to door transfer between Ella to Mirissa via Udawalawe national park. Udawalawe National Park is renowned…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Mirissa to Ella Shuttle & Safari Drive (Breakfast included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/97/f2/2c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "17",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "Key Attractions: Udawalawe National Park  Door to Door Hotel transfer:  From Mirissa, Weligama, Galle, Dickwella & suburbs…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Yala National Park Morning or Afternoon Leopard Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/0b/56/89/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "7",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "4–5 hours",
#     "description": "Our safari offers exclusive access to Yala’s wildlife in luxury 4x4 jeeps, led by expert guides. Spot leopards, elephants…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Udawalawe Safari DayTrip frm Bentota/Kalutara/Ahungalla/Hikkaduwa",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5d/c3/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "55",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "10–12 hours",
#     "description": "Udawalawe Safari Private Day Trip is organized by Bentota Travel Mart (BTM) for the tourists who stay in Wadduwa, Waskaduwa…",
#     "starting_price": "$155"
#   },
#   {
#     "title": "Udawalawe National Park | 4 Hours Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/37/af/10/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "112",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Safaris",
#     "travel_duration": "4 hours",
#     "description": "Experience a 4-Hour Safari Tour in Udawalawe!  Discover Udawalawe National Park on our 4-hour safari tour. Ideal for those…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Leopard Safari Tour in Yala National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/a6/42/f5/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "252",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Yala National Park boasts one of the densest populations of leopards in the world, and this great-value safari focuses on…",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Minneriya National Park Half day Jeep Safari with Hotel Pickup",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/b9/4b/50/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "28",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Experience the Minneriya National Park Jeep Safari, renowned for hosting South Asia's largest elephant gathering. Choose…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Minneriya National Park private safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/00/b3/d8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "93",
#     "recommendation": "Recommended by 95% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "• Morning (5.30am) or afternoon (2pm) - arrange with guide after booking.   • Hotel Pickup+and drop free of charges  only…",
#     "starting_price": "$60"
#   }
# ]
