# %% [markdown]
# Scraped along the way upto the end

# %%
# Cell 1: Import Libraries
import requests
from bs4 import BeautifulSoup
import logging
import csv
import time
import json
import re

# %%
# Cell 2: Set up Base URL and Headers
# Define a base URL without the offset parameter for pagination
# The 'oaX' offset will be inserted dynamically
base_url = 'https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html'

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
}

print("Headers configured successfully")
# Out:
# Headers configured successfully

# %%
# Initialize a list to store all scraped places from all pages
all_places_data = []

# --- Pagination Control Variables ---
offset = 0 # Starting offset for the first page
total_items = float('inf') # Will be updated after scraping the first page
items_per_page = 30 # Number of items displayed per page on Tripadvisor

# Cell 3 & 4: Create Session, Make Request, Parse, and Extract (now within a loop for pagination)
session = requests.Session()
session.headers.update(headers)

# %%
# Loop through pages until all items are collected
while offset < total_items:
    
    print(f"\n--- Current Loop Iteration ---")
    print(f"Current offset before URL construction: {offset}")

    if offset == 0:
        current_page_url = base_url
        print(current_page_url)
    else:
        # Example: 'Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html'
        # We split the base_url to insert the offset parameter correctly
        parts = base_url.rsplit('-Sri_Lanka.html', 1)
        current_page_url = f"{parts[0]}-oa{offset}-Sri_Lanka.html"
        print(current_page_url)

    print(f"Constructed URL for this page: {current_page_url}")

    # --- MODIFIED: Add retry logic for requests ---
    max_retries = 3 # Try up to 3 times for a failed request
    for attempt in range(1, max_retries + 1):

        try:
            print(f"Attempt {attempt} for URL: {current_page_url}") # New print for retry info
            response = session.get(current_page_url, timeout=20) # <--- CHANGED: Increased timeout to 20 seconds
            response.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)

            print(f"✅ Status Code for {current_page_url}: {response.status_code}")
            break # Break out of the retry loop if request is successful

        except requests.exceptions.Timeout as e:
            print(f"❌ Timeout error on attempt {attempt} for {current_page_url}: {e}")
            if attempt < max_retries:
                sleep_time = 5 * attempt # Exponential backoff: 5s, 10s, 15s delay
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
            else:
                print(f"Max retries reached for {current_page_url}. Skipping this page.")
                response = None # Set response to None to indicate failure
                break # Break out of retry loop if max attempts reached

        except requests.exceptions.RequestException as e:
            print(f"❌ Request failed on attempt {attempt} for {current_page_url}: {e}")
            if attempt < max_retries:
                sleep_time = 5 * attempt # Exponential backoff
                print(f"Retrying in {sleep_time} seconds...")
                time.sleep(sleep_time)
            else:
                print(f"Max retries reached for {current_page_url}. Skipping this page.")
                response = None # Set response to None to indicate failure
                
    # If response is None after retries, skip processing this page and move to next offset
    if response is None:
        offset += items_per_page
        time.sleep(2) # Still add a small delay before attempting next page
        continue # Skip to the next iteration of the while loop

    # Parse the HTML content for the current page
    soup = BeautifulSoup(response.text, 'html.parser')
    print("🍲 BeautifulSoup parsing completed for current page")

    # --- Extract Total Items from the first page (only once) ---
    if offset == 0:
        total_items_text_tag = soup.find('div', class_='Ci')
        if total_items_text_tag:
            full_text = total_items_text_tag.get_text(strip=True)
            match = re.search(r'of\s*([\d,]+)', full_text)
            if match:
                total_items = int(match.group(1).replace(',', ''))
                print(f"🔢 Total items identified for scraping: {total_items}")
            else:
                print("⚠️ Could not find total number of items from the first page. Assuming only one page.")
                total_items = items_per_page # Fallback: if total items not found, only process the first page
        else:
            print("⚠️ Total items text element not found. Assuming only one page.")
            total_items = items_per_page # Fallback: if element not found, only process the first page

    # --- Data Extraction Logic (your existing robust extraction) ---
    listings = soup.find_all('article', class_='GTuVU XJlaI rHoxO')
    print(f"Found {len(listings)} listings on this page.")

    if not listings:
        print(f"🚫 No new listings found on {current_page_url}. This might be the last page or an empty page. Ending scrape.")
        break # Exit loop if no listings are found on the current page

    for listing in listings:
        place_details = {}

        # Extract Title
        title_tag = listing.find('h3', class_='biGQs _P fiohW OgHoE')
        if title_tag:
            title_text = title_tag.get_text(strip=True)
            place_details['title'] = re.sub(r'^\d+\.\s*', '', title_text).strip()
        else:
            place_details['title'] = 'N/A'

        # Extract Image links
        image_links = []
        image_container = listing.find('div', class_='IdURT w carousel UznXc wSSLS')
        if image_container:
            img_tags = image_container.find_all('img', src=True)
            for img_tag in img_tags:
                src = img_tag['src']
                if not src.startswith('data:image/svg+xml'):
                    if src.startswith('//'):
                        src = 'https:' + src
                    image_links.append(src)
        place_details['image_links'] = image_links if image_links else 'N/A'

        # Extract Rating
        rating_tag = listing.find('div', {'data-automation': 'bubbleRatingValue'})
        if rating_tag:
            place_details['rating'] = rating_tag.find('span').get_text(strip=True)
        else:
            place_details['rating'] = 'N/A'

        # Extract Total Reviews
        reviews_tag = listing.find('div', {'data-automation': 'bubbleLabel'})
        if reviews_tag:
            place_details['total_reviews'] = reviews_tag.get_text(strip=True)
        else:
            place_details['total_reviews'] = 'N/A'

        # Extract Recommendation
        recommendation_tag = listing.find('span', class_='biGQs _P pZUbB egaXP ZNjnF', string=lambda text: text and 'Recommended by' in text)
        if recommendation_tag:
            place_details['recommendation'] = recommendation_tag.get_text(strip=True)
        else:
            place_details['recommendation'] = 'N/A'

        # Extract Type
        type_div = listing.find('div', class_='alPVI eNNhq PgLKC tnGGX yzLvM')
        if type_div:
            type_element = None
            all_text_divs = type_div.find_all('div', class_='biGQs _P pZUbB ZNjnF')
            for div in all_text_divs:
                if not div.find_parent('div', class_='bRMrl _Y K fOSqw') and \
                   not div.find_parent('div', {'data-automation': 'listCardDescription'}) and \
                   not div.find_parent('div', {'data-automation': 'cardPrice'}) and \
                   not "cancellation" in div.get_text(strip=True).lower() and \
                   not "recommended by" in div.get_text(strip=True).lower():
                    type_element = div
                    break
            if type_element:
                place_details['type'] = type_element.get_text(strip=True)
            else:
                place_details['type'] = 'N/A'
        else:
            place_details['type'] = 'N/A'

        # Extract Travel Duration
        duration_tag = listing.find('div', class_='bRMrl _Y K fOSqw')
        if duration_tag:
            duration_element = duration_tag.find('div', class_='biGQs _P pZUbB ZNjnF')
            if duration_element:
                place_details['travel_duration'] = duration_element.get_text(strip=True)
            else:
                place_details['travel_duration'] = 'N/A'
        else:
            place_details['travel_duration'] = 'N/A'

        # Extract Description
        description_tag = listing.find('div', {'data-automation': 'listCardDescription'})
        if description_tag:
            span_tag = description_tag.find('span', class_='SwTtt')
            if span_tag:
                description_text = span_tag.get_text(strip=True).replace('\n', ' ').strip()
                if not description_text.endswith('…') and '…' in span_tag.text:
                    description_text += '…'
                place_details['description'] = description_text
            else:
                place_details['description'] = 'N/A'
        else:
            place_details['description'] = 'N/A'

        # Extract Starting Price
        price_tag = listing.find('div', {'data-automation': 'cardPrice'})
        if price_tag:
            place_details['starting_price'] = price_tag.get_text(strip=True)
        else:
            place_details['starting_price'] = 'N/A'
        pass
        all_places_data.append(place_details)

    # Increment the offset for the next page
    offset += items_per_page
    print(f"Offset for next page: {offset}")

    # Add a delay between requests to be polite and avoid being blocked
    time.sleep(3) # IMPORTANT: Adjust this value as needed, typically 1-5 seconds

# Final output: print all collected data after the loop finishes
print(f"\n✅ Scraped {len(all_places_data)} items across all pages.")
print(json.dumps(all_places_data, indent=2, ensure_ascii=False))
# Out:
# --- Current Loop Iteration ---
# Current offset before URL construction: 0
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# 🔢 Total items identified for scraping: 1103
# Found 30 listings on this page.
# Offset for next page: 30
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 30
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa30-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 60
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 60
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa60-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa60-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa60-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa60-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 90
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 90
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa90-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa90-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa90-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa90-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 120
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 120
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa120-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa120-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa120-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa120-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 150
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 150
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa150-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa150-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa150-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa150-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 180
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 180
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa180-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa180-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa180-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa180-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 210
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 210
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa210-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa210-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa210-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa210-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 240
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 240
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa240-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa240-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa240-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa240-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 270
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 270
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa270-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa270-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa270-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa270-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 300
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 300
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa300-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa300-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa300-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa300-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 330
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 330
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa330-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa330-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa330-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa330-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 360
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 360
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa360-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa360-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa360-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa360-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 390
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 390
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa390-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa390-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa390-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa390-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 420
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 420
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa420-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa420-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa420-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa420-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 450
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 450
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa450-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa450-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa450-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa450-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 480
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 480
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa480-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa480-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa480-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa480-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 510
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 510
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa510-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa510-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa510-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa510-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 540
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 540
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa540-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa540-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa540-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa540-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 570
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 570
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa570-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa570-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa570-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa570-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 600
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 600
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa600-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa600-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa600-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa600-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 630
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 630
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa630-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa630-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa630-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa630-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 660
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 660
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa660-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa660-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa660-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa660-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 690
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 690
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa690-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa690-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa690-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa690-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 720
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 720
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa720-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa720-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa720-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa720-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 750
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 750
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa750-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa750-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa750-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa750-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 780
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 780
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa780-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa780-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa780-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa780-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 810
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 810
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa810-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa810-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa810-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa810-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 840
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 840
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa840-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa840-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa840-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa840-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 870
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 870
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa870-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa870-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa870-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa870-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 900
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 900
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html
# ❌ Timeout error on attempt 1 for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html: HTTPSConnectionPool(host='www.tripadvisor.com', port=443): Read timed out. (read timeout=20)
# Retrying in 5 seconds...
# Attempt 2 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa900-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 930
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 930
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa930-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa930-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa930-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa930-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 960
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 960
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa960-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa960-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa960-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa960-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 990
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 990
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa990-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa990-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa990-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa990-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1020
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1020
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1020-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1020-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1020-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1020-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1050
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1050
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1050-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1050-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1050-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1050-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 30 listings on this page.
# Offset for next page: 1080
#
# --- Current Loop Iteration ---
# Current offset before URL construction: 1080
# https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1080-Sri_Lanka.html
# Constructed URL for this page: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1080-Sri_Lanka.html
# Attempt 1 for URL: https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1080-Sri_Lanka.html
# ✅ Status Code for https://www.tripadvisor.com/Attractions-g293961-Activities-c61-t243-oa1080-Sri_Lanka.html: 200
# 🍲 BeautifulSoup parsing completed for current page
# Found 23 listings on this page.
# Offset for next page: 1110
#
# ✅ Scraped 1103 items across all pages.
# [
#   {
#     "title": "Ella: Transfer to Tangalle/Mirissa/Galle & Yala/Udawalawe Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/15/e8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "30",
#     "recommendation": "Recommended by 93% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "8–10 hours",
#     "description": "After pick-up from your hotel in Ella, head for Udawalawe Or Yala National Park, where you'll switch to an open concept …",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park to Visit Elephants",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/c8/cb/5e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "216",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "Attention: According to the weather conditions, Minneriya National Park, and Kaudulla NP are the best these days. You can…",
#     "starting_price": "$35"
#   },
#   {
#     "title": "Special leopards safari Yala National park - 04.30 am to 11.30 am",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/02/e4/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "154",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "People who like to see more wild life this is the perfect tour with janaka safari,  we do our best for the leopard. start…",
#     "starting_price": "$49"
#   },
#   {
#     "title": "Private Jeep Safari at Minneriya National Park - Half Day Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/d8/b1/a2/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "40",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "3–4 hours",
#     "description": "We arrange a Comfortable and private vehicle for you. The prices include hotel pick-up and drop-off. We offer a Knowledgeable…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Udawalawe National Park | Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/24/45/64/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "1,068",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Udawalawe National Park is a destination to see elephants. Other animals in the park include leopards, jungle cats, monkeys…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Yala National Park Special Leopard Safari Tours By Dinuka Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/e9/25/6a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "64",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "7–13 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$22"
#   },
#   {
#     "title": "Full day Safari - Yala National Park - 04.30 am to 06.00 pm with - Janaka safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/0b/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "462",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "The leopard is the key attraction to Yala National Park:   “Showing the leopard is our mission”  Other Animals  There are…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Yala National Park Wildlife Safari/ Game Drive - by Ajith Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/7c/b6/a9/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "214",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Explore breathtaking wilderness of Sri Lanka with Ajith Safari Jeep Tours. We're the only Sri Lankan safari operator mentioned…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Wilpattu National Park Safari | Jeep with Tickets",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/b2/34/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "101",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–12 hours",
#     "description": "The park is 1,317 square kilometers (131, 693 hectares) and ranges from 0 to 152 meters above sea level. Nearly one hundred…",
#     "starting_price": "$95"
#   },
#   {
#     "title": "Minneriya National Park halfday Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/24/0c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "224",
#     "recommendation": "Recommended by 99% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "To reserve a national park, please choose one from the options provided. Each reservation is for one park only, and you …",
#     "starting_price": "$50"
#   },
#   {
#     "title": "Full day / Half Day WildlifeAdventure in Yala-National-Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/38/3b/98/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "239",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Photography Tours",
#     "travel_duration": "1 day",
#     "description": "Yala harbours 215 bird species including six endemic species of Sri Lanka. The number of mammals that has been recorded …",
#     "starting_price": "$42"
#   },
#   {
#     "title": "Udawalawe National Park Half Day Jeep Safari (Private Tour)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/a2/b7/59/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "62",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "You have the option of either arranging for hotel pickup or heading directly to the Udawalawe National Park gate, where …",
#     "starting_price": "$24"
#   },
#   {
#     "title": "Kumana National Park Half Day Jeep Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4d/87/c6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "32",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–6 hours",
#     "description": "visit to the Kumana National Park is a must-do activity when you holiday at Arugam Bay and we are delighted to organize …",
#     "starting_price": "$88"
#   },
#   {
#     "title": "Wilpattu Half Day Safari From Anuradhapura",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/96/23/e1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "Join us for an exhilarating safari in Wilpattu National Park, starting at 5:00 AM, where you have a prime opportunity to…",
#     "starting_price": "$73"
#   },
#   {
#     "title": "Minneriya National Park Elephant Jeep Safari Private Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/af/03/0e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "35",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "3–5 hours",
#     "description": "The biggest concentration of wild Asian elephants in the entire world may be found in Sri Lanka’s Minneriya National Park…",
#     "starting_price": "$53"
#   },
#   {
#     "title": "2h Bentota River Safari: Crocodiles, Monkeys, Mangrove & more",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/68/bb/d0/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "73",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "Embark on the Bentota River Boat Safari with us and immerse yourself in a world where nature's tranquility meets wild beauty…",
#     "starting_price": "$33"
#   },
#   {
#     "title": "Leopard Safari Tour in Yala National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/a6/42/f5/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "252",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4–14 hours",
#     "description": "Yala National Park boasts one of the densest populations of leopards in the world, and this great-value safari focuses on…",
#     "starting_price": "$20"
#   },
#   {
#     "title": "Day Tour from kandy to Sigiriya, Dambulla & National Park safari.",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/f1/05/3b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "14",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "Sigiriya today is a UNESCO-listed World Heritage Site. It is one of the best-preserved examples of ancient urban planning…",
#     "starting_price": "$55"
#   },
#   {
#     "title": "Wilpattu National Park Jeep Safari from Negombo / Waikkal (All Inclusive)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/22/f6/58/d6/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "83",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "10–16 hours",
#     "description": "Today you will enjoy an adventurous full-day safari at Wilpattu National Park including breakfast and lunch at the Park. …",
#     "starting_price": "$152"
#   },
#   {
#     "title": "Negombo Lagoon Boat Safari From Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/c3/72/1a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "8",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "2–3 hours",
#     "description": "This safari is a must-do for nature lovers and anyone looking for a scenic retreat because it guarantees a tranquil break…",
#     "starting_price": "$43"
#   },
#   {
#     "title": "Yala National Park Tour From Hambantota Port",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/c7/f2/14/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "31",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6–7 hours",
#     "description": "This Yala safari tour offers a unique experience by combining wildlife adventure with breathtaking landscapes. Unlike other…",
#     "starting_price": "$48"
#   },
#   {
#     "title": "Safari Tour at Minneriya National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/5d/bc/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "19",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "5 hours",
#     "description": "Bunches of Elephants can be seen in their natural behavior and visitors will be amazed to see hundreds in bunch. You will…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Half Day Tour to Muthurajawela, Lagoon, Dutch Canal and Mangroves",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/19/20/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "5",
#     "recommendation": "N/A",
#     "type": "Private Sightseeing Tours",
#     "travel_duration": "3 hours",
#     "description": "Half day tour to explore different seaside attractions with a ride through the Dutch Canal, Negombo lagoon and Muthurajawela…",
#     "starting_price": "$59"
#   },
#   {
#     "title": "Ella to Mirissa Shuttle & Safari Drive (Breakfast Included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fa/69/36/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.6",
#     "total_reviews": "21",
#     "recommendation": "Recommended by 90% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Enjoy a seamless door to door transfer between Ella to Mirissa via Udawalawe national park. Udawalawe National Park is renowned…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Mirissa to Ella Shuttle & Safari Drive (Breakfast included)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/97/f2/2c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "17",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "Key Attractions: Udawalawe National Park  Door to Door Hotel transfer:  From Mirissa, Weligama, Galle, Dickwella & suburbs…",
#     "starting_price": "$40"
#   },
#   {
#     "title": "Yala National Park Morning or Afternoon Leopard Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/0b/56/89/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "7",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "4–5 hours",
#     "description": "Our safari offers exclusive access to Yala’s wildlife in luxury 4x4 jeeps, led by expert guides. Spot leopards, elephants…",
#     "starting_price": "$18"
#   },
#   {
#     "title": "Udawalawe Safari DayTrip frm Bentota/Kalutara/Ahungalla/Hikkaduwa",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5d/c3/15/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "55",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "10–12 hours",
#     "description": "Udawalawe Safari Private Day Trip is organized by Bentota Travel Mart (BTM) for the tourists who stay in Wadduwa, Waskaduwa…",
#     "starting_price": "$155"
#   },
#   {
#     "title": "Udawalawe National Park | 4 Hours Private Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/37/af/10/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "112",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Safaris",
#     "travel_duration": "4 hours",
#     "description": "Experience a 4-Hour Safari Tour in Udawalawe!  Discover Udawalawe National Park on our 4-hour safari tour. Ideal for those…",
#     "starting_price": "$30"
#   },
#   {
#     "title": "Minneriya National Park Half day Jeep Safari with Hotel Pickup",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2c/b9/4b/50/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "28",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Experience the Minneriya National Park Jeep Safari, renowned for hosting South Asia's largest elephant gathering. Choose…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Yala National Park Safari Tours -Half Day & Full Day",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/bc/ea/c1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "28",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "7–12 hours",
#     "description": "​Yala National Park is a huge area of forest. It is home to wildlife such as leopards, elephants, sloth bears, monkeys, …",
#     "starting_price": "$22"
#   },
#   {
#     "title": "Minneriya National Park private safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/00/b3/d8/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "93",
#     "recommendation": "Recommended by 95% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "3–4 hours",
#     "description": "• Morning (5.30am) or afternoon (2pm) - arrange with guide after booking.   • Hotel Pickup+and drop free of charges  only…",
#     "starting_price": "$60"
#   },
#   {
#     "title": "Yala Safari Tour from Hambantota Port by Ajith Safaris",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/e3/a8/13/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "50",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "5–6 hours",
#     "description": "This is the only Yala/Udawalawa safari tour crafted specifically for cruise passengers docking at Hambantota Port. We understand…",
#     "starting_price": "$50"
#   },
#   {
#     "title": "Bentota River Safari By BTM (Mangrove & Wildlife Encounter)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/1e/9d/aa/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "80",
#     "recommendation": "Recommended by 96% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "2 hours",
#     "description": "Bentota River Boat Safari is organized by Bentota Travel Mart ( BTM ) for the travelers who are in Bentota, Induruwa, Kosgoda…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Full Day Safari Tour in Yala National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/0a/2c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "55",
#     "recommendation": "Recommended by 96% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "8–12 hours",
#     "description": "This tour we can show you lot of wild life and nice landscapes in Yala National park. Our main aim is to show you the leopards…",
#     "starting_price": "$108"
#   },
#   {
#     "title": "Ella to Mirissa Shuttle & Udawalawe national Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/49/aa/42/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "54",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "Save your time and money by coming from hotel in Ella or its surroundings and travel to your destination Mirissa or near…",
#     "starting_price": "$50"
#   },
#   {
#     "title": "Special Leopards safari - Yala National park - 04.30 am to 11.30 am",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4d/59/6e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "34",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "6+ hours",
#     "description": "We Yala Osha Safari have been doing safari for many years ; showing leopard is our mission during Yala   Special 5-12 (Five…",
#     "starting_price": "$76"
#   },
#   {
#     "title": "Bundala National Park Birds Watching Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/43/58/eb/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "12",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Photography Tours",
#     "travel_duration": "4 hours",
#     "description": "This is a most best experience for you life You can see wild life animals specially lot of kind of birds and Elephants, …",
#     "starting_price": "$34"
#   },
#   {
#     "title": "Sigiriya & Habarana: Sunrise Hot Air Balloon Ride Experience",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/83/a7/5c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "16",
#     "recommendation": "Recommended by 93% of travelers",
#     "type": "Extreme Sports",
#     "travel_duration": "4 hours",
#     "description": "From the moment you book, we take care of everything—no stress, just adventure! Our air-conditioned vehicles will pick you…",
#     "starting_price": "$275"
#   },
#   {
#     "title": "Yala National Park Safari Tour From Hambantota port",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/5e/b0/26/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "43",
#     "recommendation": "Recommended by 97% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "5–6 hours",
#     "description": "Experience the Wild Like Never Before!  Pick up and drop off from Hambantota Port and Hambantota area Hotels are free   …",
#     "starting_price": "$49"
#   },
#   {
#     "title": "Yala National Park - Full Day Safari (04:30 am - 06:00 pm)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/b3/19/d3/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "123",
#     "recommendation": "Recommended by 98% of travelers",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "Embark on an unforgettable adventure with our Full Day Safari to Yala National Park, one of Sri Lanka's most renowned wildlife…",
#     "starting_price": "$99"
#   },
#   {
#     "title": "Yala Safari Private Day Trip with Return Transport -All Inclusive",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/61/17/c1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "28",
#     "recommendation": "Recommended by 92% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "8–10 hours",
#     "description": "Yala Safari Private Day Trip is organized by Bentota Travel Mart (BTM) for the tourists who stay in Galle, Unawatuna, Talpe…",
#     "starting_price": "$95"
#   },
#   {
#     "title": "From Ella Shuttle to Tangalle/Mirissa/Galle with Yala Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/14/6c/63/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "6+ hours",
#     "description": "This is our warm invitation for you to explore breathtaking wilderness of Sri Lanka. From Ella, moving to the sandy beaches…",
#     "starting_price": "$45"
#   },
#   {
#     "title": "Muthurajawela Bird Watching Tour From Colombo & Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/69/09/d3/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "13",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "2–5 hours",
#     "description": "Embark on an exhilarating birdwatching adventure in Muthurajawela, a haven for nature enthusiasts near Negombo & Colombo…",
#     "starting_price": "$85"
#   },
#   {
#     "title": "Private Jeep Safari To one of a Best National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5e/07/6a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.4",
#     "total_reviews": "14",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "4–11 hours",
#     "description": "Enjoy thrilling look at the elephants of Minneriya National Park , Kaudulla National Park Or Hurulu Eco Park, during this…",
#     "starting_price": "$85"
#   },
#   {
#     "title": "Evening Safari - Yala National Park with Janaka safari - 02.00 pm to 06.30 pm",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4d/86/dd/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "38",
#     "recommendation": "Recommended by 94% of travelers",
#     "type": "Private and Luxury",
#     "travel_duration": "4 hours",
# ...
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4c/c2/55/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "21",
#     "recommendation": "Recommended by 100% of travelers",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Start your day with a visit to the iconic Sigiriya Lion Rock, a UNESCO World Heritage Site and one of Sri Lanka’s most renowned…",
#     "starting_price": "$34"
#   },
#   {
#     "title": "Half Day trip in Yala National Park",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2e/8b/d9/64/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "4–12 hours",
#     "description": "Embark on an extraordinary wildlife adventure with us, backed by over 40 years of expertise in leopard tracking at Yala …",
#     "starting_price": "$72"
#   },
#   {
#     "title": "Yala National Park Full Day Safari Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/f8/6e/b3/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "10–12 hours",
#     "description": "Embark on an extraordinary wildlife adventure with us, backed by over 40 years of expertise in leopard tracking at Yala …",
#     "starting_price": "$96"
#   },
#   {
#     "title": "Ancient Kingdom and Wild Elephant Safari from Polonnaruwa",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/86/bf/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "2",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Enjoy personalized attention and the ability to travel at your own pace on this private tour of Polonnaruwa and Minneriya…",
#     "starting_price": "$78"
#   },
#   {
#     "title": "Hurulu Eco Park Safari | Jeep with Tickets",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/3e/62/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "2",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "3 hours",
#     "description": "The Hurulu Eco Park Safari takes you on a tour through part of the Hurulu biosphere reserve. You can select either the morning…",
#     "starting_price": "$51"
#   },
#   {
#     "title": "Udawalawe National Park Best Private Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/14/3b/bd/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "2",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "We are sri lankan best safari service and we can made your tour perfect. we have 6 years experience with our safari service…",
#     "starting_price": "$32"
#   },
#   {
#     "title": "Udawalawe National Park Safari from Hambantota Seaport",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/42/ff/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6 hours",
#     "description": "Enter the Land of Elephants as you go on a 3-hour Udawalawe National Park Safari! Search for sightings of the giants of …",
#     "starting_price": "$98"
#   },
#   {
#     "title": "05 Days Wild Life Tour [Tour plane 02]",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5b/20/26/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "5.0",
#     "total_reviews": "1",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "Considering a Sri Lankan wildlife safari adventure tour? Consult our team of travel experts who will help you plan your …",
#     "starting_price": "$315"
#   },
#   {
#     "title": "Kaudulla National Park Shared Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/03/3a/65/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.9",
#     "total_reviews": "7",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "3 hours",
#     "description": "The Kaudulla National Park Safari allows you to see the wild fauna of Sri Lanka in their natural habitats. Travel along …",
#     "starting_price": "$35"
#   },
#   {
#     "title": "Yala Safari Drive From Ella",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/01/23/54/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.8",
#     "total_reviews": "4",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "In order to grab the best, we'll start early 5AM, from Ella, Bandarawela, suburbs. Upon arrival at the meeting point you…",
#     "starting_price": "$65"
#   },
#   {
#     "title": "One Day Safari Tour to Both Yala and Bundala National Parks",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/61/12/27/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.7",
#     "total_reviews": "3",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "10–12 hours",
#     "description": "5:00am: You will be picked up from your hotel in Yala, Kataragama, Tissamaharama, Palatupana, Kirinda, Weerawila, Hambantota…",
#     "starting_price": "$230"
#   },
#   {
#     "title": "Day Excursion to Yala National Park From Colombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2b/9d/12/96/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "4.0",
#     "total_reviews": "2",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "10–12 hours",
#     "description": "Experience a nature-friendly wildlife tour. An air-conditioned vehicle will pick you up from your hotel and transport you…",
#     "starting_price": "$134"
#   },
#   {
#     "title": "Udawalawe National Park Safari from Mount Lavinia",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/99/ba/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Udawalawe National Park, the sixth largest animal sanctuary of Sri Lanka, is located 112 miles (180 km) from Colombo in …",
#     "starting_price": "$158"
#   },
#   {
#     "title": "Udawalawe National Park Safari from Ella",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/90/2e/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Udawalawe National Park, the sixth largest animal sanctuary of Sri Lanka, is located 112 miles (180 km) from Colombo in …",
#     "starting_price": "$92"
#   },
#   {
#     "title": "Wildlife of Sri Lanka (10 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/8b/fd/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "Wildlife of Sri Lanka is a nature lover’s ideal holiday experience. The tropics of Sri Lanka has many wildlife conversations…",
#     "starting_price": "$330"
#   },
#   {
#     "title": "Wasgamuwa National Park Safari from Habarana",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/19/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Wasgamuwa National Park is a haven for many species of flora and displaced fauna. Nature lovers find Wasgamuwa interesting…",
#     "starting_price": "$89"
#   },
#   {
#     "title": "Lahugala Kitulana National Park Private Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/92/0f/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Safaris",
#     "travel_duration": "3 hours",
#     "description": "This safari takes you on a wonderful wildlife experience in lahugala National Park, Get a chance to see the elusive Sri …",
#     "starting_price": "$27"
#   },
#   {
#     "title": "Polonnaruwa Ancient Kingdom and Wild Elephant Safari from Dambulla",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/8d/69/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "This tour takes you to Polonnaruwa and Minneriya, on a remarkable archaeological and nature-filled journey. Wonder at the…",
#     "starting_price": "$81"
#   },
#   {
#     "title": "Yala National Park Safari | From Ella",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5b/76/87/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Yala National Park is a huge area of forest, grassland and lagoons bordering the Indian Ocean, in southeast Sri Lanka. It…",
#     "starting_price": "$95"
#   },
#   {
#     "title": "Kalawewa National Park Guided 4WD Safari",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2a/27/94/7b/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "The imposing Kala Wewa and Balalu Wewa tanks built in the 5th century BC by King Dhatusena adorns the 6000-hectare Kalawewa…",
#     "starting_price": "$63"
#   },
#   {
#     "title": "Polonnaruwa and Minneriya Safari from Kandy",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/b0/6f/55/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Polonnaruwa, or Pulasthi Nakaram as it was also called, was the second capital of the ancient Sri Lankan Kings; the first…",
#     "starting_price": "$176"
#   },
#   {
#     "title": "LGBT Friendly Tour in Paradise Island (15 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/b0/59/d1/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Private and Luxury",
#     "travel_duration": "3+ days",
#     "description": "An ideal holiday to get away from the stressful day to day routine, the Small Miracle tour consists of a mix of adventure…",
#     "starting_price": "$491"
#   },
#   {
#     "title": "Wild Wonders and Sacred Spaces Tour from Hikkaduwa (2 Days)",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fb/90/17/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Overnight Tours",
#     "travel_duration": "2 days",
#     "description": "Wild Wonders & Sacred Spaces is a short, single night, 2-day tour that combines culture and wildlife in the Northern Central…",
#     "starting_price": "$183"
#   },
#   {
#     "title": "Udawalawe Day Trip from Kalutara",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/5a/ee/f7/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Car Tours",
#     "travel_duration": "12–15 hours",
#     "description": "Explore the diverse wildlife of Udawalawa National Park on an exhilarating safari, where you'll get a chance to see elephants…",
#     "starting_price": "$109"
#   },
#   {
#     "title": "Udawalawe National Park Safari | From Colombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/fe/aa/6a/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Day Trips",
#     "travel_duration": "6+ hours",
#     "description": "Udawalawe National Park lies on the boundary of Sabaragamuwa and Uva Provinces, in Sri Lanka. The national park was created…",
#     "starting_price": "$133"
#   },
#   {
#     "title": "Minneriya Jeep Safari from Habarana Hotels",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/60/4c/52/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "4 hours",
#     "description": "Minneriya Jeep Safari is a one of the most popular activity among travelers who visit Sri Lanka. The safari can be customized…",
#     "starting_price": "$180"
#   },
#   {
#     "title": "Private 8 day tour in Sri Lanka 2020 - Only for groups above 7 pax.",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1a/5d/d5/f5/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Multi-day Tours",
#     "travel_duration": "3+ days",
#     "description": "Spend 8 days in Sri Lanka experiencing its beautiful cities, historical and wildlife attractions, and UNESCO World Heritage…",
#     "starting_price": "$988"
#   },
#   {
#     "title": "Adventure tour in Sri Lanka for 9 days",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/53/db/17/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "3+ days",
#     "description": "Adventure tour in Sri Lanka for 9 days is a full guide on how to spend a 9-day wildlife tour in Sri Lanka, don't skip any…",
#     "starting_price": "$1,025"
#   },
#   {
#     "title": "Sri Lanka 7 Day Tour | All Inclusive",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/60/95/5c/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "3+ days",
#     "description": "Enjoy this 7 Day tour by visiting iconic attractions and destinations in Sri Lanka with your own private driver/guide. Your…",
#     "starting_price": "$889"
#   },
#   {
#     "title": "Sri Lanka 7 days Round Tour, Beaches & Safari Island Full Tour",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2f/63/24/50/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "Car Tours",
#     "travel_duration": "3+ days",
#     "description": "*Accommodation on Double / Twin sharing basis as per itinerary  *Stay 4* Hotels with BB Basis  *Daily breakfast  *Private…",
#     "starting_price": "$750"
#   },
#   {
#     "title": "Day Excursion To Yala National Park From Negombo",
#     "image_links": [
#       "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/14/4d/87/caption.jpg?w=500&h=400&s=1"
#     ],
#     "rating": "N/A",
#     "total_reviews": "N/A",
#     "recommendation": "N/A",
#     "type": "4WD Tours",
#     "travel_duration": "10–12 hours",
#     "description": "Experience a nature-friendly wildlife tour. An air-conditioned vehicle will pick you up from your hotel and transport you…",
#     "starting_price": "$120"
#   }
# ]

# %%
print(len(all_places_data))
# Out:
# 1103

# %%
# Cell X: Save to CSV File
import csv # Ensure this import is at the top of your script if not already there

csv_file_name = 'sri_lanka_safaris.csv'

# Determine the fieldnames (column headers) from the keys of the first dictionary
# This assumes all dictionaries have the same keys.
if all_places_data:
    fieldnames = list(all_places_data[0].keys()) # Convert to list for DictWriter
else:
    fieldnames = [] # Handle case where no data was scraped

try:
    with open(csv_file_name, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader() # Write the header row
        for row in all_places_data:
            # Ensure image_links are joined into a string if they are a list, for CSV compatibility
            if isinstance(row.get('image_links'), list):
                cleaned_image_links = []
                for link in row['image_links']:
                    # Remove query parameters from each link
                    # This splits the URL at the first '?' and takes the first part
                    cleaned_link = link.split('?', 1)[0]
                    cleaned_image_links.append(cleaned_link)
                
                row['image_links'] = ', '.join(cleaned_image_links) # Join the cleaned links
            
            writer.writerow(row) # Write each row

    print(f"\n✅ Data successfully saved to {csv_file_name}")

except IOError as e:
    print(f"❌ Error writing to CSV file {csv_file_name}: {e}")
# Out:
# ✅ Data successfully saved to sri_lanka_safaris.csv
